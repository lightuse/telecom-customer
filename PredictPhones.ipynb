# %% [markdown]
# How can I recommend a device to a customer?
#
# Below is the data for this time.
#
# * mou_Mean Mean number of monthly minutes of use
# * totmrc_Mean Mean total monthly recurring charge
# * ovrrev_Mean Mean overage revenue
# * change_mou Percentage change in monthly minutes of use vs previous three month average month average
# * unan_vce_Mean Mean number of unanswered voice calls
# * cc_mou_Mean Mean unrounded minutes of use of customer care (see CUSTCARE_MEAN) calls
# * churn Instance of churn between 31–60 days after observation date
# * months Total number of months in service
# * crclscod Credit class code
# * totcalls Total number of calls over the life of the customer
# * totmou Total minutes of use over the life of the customer
# totrev Total revenue
# * adjrev Billing adjusted total revenue over the life of the customer
# * adjqty Billing adjusted total number of calls over the life of the customer
# * avgrev Average monthly revenue over the life of the customer
# * avgmou Average monthly minutes of use over the life of the customer
# * avgqty Average monthly number of calls over the life of the customer
# * avg6rev Average monthly revenue over the previous six months
# * area Geogrpahic area
# * hnd_price Current handset price
# * phones Number of handsets issued
# * models Number of models issued
# * eqpdays Number of days (age) of current equipment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
input_data_dir = ""
output_data_dir = ""

# %%
# type
my_dtype = {
    'Customer_ID':float,
    'rev_Mean':float,
    'mou_Mean':float,
    'totmrc_Mean':float,
    'da_Mean':float,
    'ovrmou_Mean':float,
    'vceovr_Mean':float,
    'datovr_Mean':float,
    'roam_Mean':float,
    'change_mou':float,
    'change_rev':float,
    'drop_vce_Mean':float,
    'drop_dat_Mean':float,
    'blck_vce_Mean':float,
    'blck_dat_Mean':float,
    'unan_vce_Mean':float,
    'unan_dat_Mean':float,
    'plcd_vce_Mean':float,
    'plcd_dat_Mean':float,
    'recv_vce_Mean':float,
    'recv_sms_Mean':float,
    'comp_vce_Mean':float,
    'comp_dat_Mean':float,
    'custcare_Mean':float,
    'ccrndmou_Mean':float,
    'cc_mou_Mean':float,
    'inonemin_Mean':float,
    'threeway_Mean':float,
    'mou_cvce_Mean':float,
    'mou_cdat_Mean':float,
    'mou_rvce_Mean':float,
    'owylis_vce_Mean':float,
    'mouowylisv_Mean':float,
    'iwylis_vce_Mean':float,
    'mouiwylisv_Mean':float,
    'peak_vce_Mean':float,
    'peak_dat_Mean':float,
    'mou_peav_Mean':float,
    'mou_pead_Mean':float,
    'opk_vce_Mean':float,
    'opk_dat_Mean':float,
    'mou_opkv_Mean':float,
    'mou_opkd_Mean':float,
    'drop_blk_Mean':float,
    'attempt_Mean':float,
    'complete_Mean':float,
    'callfwdv_Mean':float,
    'callwait_Mean':float,
    'churn':float,
    'months':float,
    'uniqsubs':float,
    'actvsubs':float,
    'new_cell':object,
    'crclscod':object,
    'asl_flag':object,
    'totcalls':float,
    'totmou':float,
    'totrev':float,
    'adjrev':float,
    'adjmou':float,
    'adjqty':float,
    'avgrev':float,
    'avgmou':float,
    'avgqty':float,
    'avg3mou':float,
    'avg3qty':float,
    'avg3rev':float,
    'avg6mou':float,
    'avg6qty':float,
    'avg6rev':float,
    'prizm_social_one':object,
    'area':object,
    'dualband':object,
    'refurb_new':object,
    'hnd_price':float,
    'phones':float,
    'models':float,
    'hnd_webcap':object,
    'truck':float,
    'rv':float,
    'ownrent':object,
    'lor':float,
    'dwlltype':object,
    'marital':object,
    'adults':float,
    'infobase':object,
    'income':float,
    'numbcars':float,
    'HHstatin':object,
    'dwllsize':object,
    'forgntvl':float,
    'ethnic':object,
    'kid0_2':object,
    'kid3_5':object,
    'kid6_10':object,
    'kid11_15':object,
    'kid16_17':object,
    'creditcd':object,
    'eqpdays':float,
}
categorical_features = [
   'new_cell',
   'crclscod',
   'asl_flag',
   'area',
   'dualband',
   'refurb_new',
   'hnd_webcap',
   'ownrent',
   'dwlltype',
   'marital',
   'infobase',
   'HHstatin',
   'dwllsize',
   'ethnic',
   'kid0_2',
   'kid3_5',
   'kid6_10',
   'kid11_15',
   'kid16_17',
   'creditcd',
   'prizm_social_one'
]
target_label = ['phones']
train_file_name = input_data_dir + 'Telecom_customer churn.csv'

# %%
import pandas as pd
def input_train_file(filename, my_dtype):

    df = pd.read_csv(train_file_name, header=0, dtype=my_dtype)
    for column in target_label:
        y = df[column]
    X = df.drop(target_label, axis=1)
    X = X.reset_index(drop=True)
    print('missing value all count:input_train_file', X.isnull().sum().sum())
    print('missing value count per column:input_train_file', X.isnull().sum())
    return df, X, y

# %%
df, X, y = input_train_file(train_file_name, my_dtype)
# Out:
# missing value all count:input_train_file 342968
# missing value count per column:input_train_file rev_Mean        357
# mou_Mean        357
# totmrc_Mean     357
# da_Mean         357
# ovrmou_Mean     357
#                ...
# kid11_15       1732
# kid16_17       1732
# creditcd       1732
# eqpdays           1
# Customer_ID       0
# Length: 99, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(df[['phones', 'months', 'eqpdays', 'totrev', 'hnd_price', 'totmou', 'adjqty', 'avgrev', 'avgmou', 'totmrc_Mean', 'models', 'avg6rev', 'ovrrev_Mean']].corr(), annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
import lightgbm as lgb

# %%
def clean_data(df):
    '''
    INPUT
    df - pandas dataframe

    OUTPUT
    X - A matrix holding all of the variables you want to consider when predicting the response
    y - the corresponding response vector

    This function cleans df using the following steps to produce X and y:
    1. Drop all the rows with no salaries
    2. Create X as all the columns that are not the Salary column
    3. Create y as the Salary column
    4. Drop the Salary, Respondent, and the ExpectedSalary columns
    5. For each numeric variable, fill the column with the mean value.
    6. Create dummy columns for all the categorical variables, drop the original columns
    '''
    # Drop rows with missing salary values
    df = df.dropna(subset=['phones'], axis=0)
    y = df['phones']

    #Drop respondent and expected salary columns
    df = df.drop(['phones', 'Customer_ID'], axis=1)

    # Fill numeric columns with the mean
    num_vars = df.select_dtypes(include=['float', 'int']).columns
    for col in num_vars:
        df[col].fillna((df[col].mean()), inplace=True)

    # Dummy the categorical variables
    cat_vars = df.select_dtypes(include=['object']).copy().columns
    for var in  cat_vars:
        # for each cat add dummy var, drop original column
        df = pd.concat([df.drop(var, axis=1), pd.get_dummies(df[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)

    X = df
    return X, y

# %%
X, y = clean_data(df)

# %%
pd.set_option('display.max_rows', None)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model = lgb.LGBMRegressor(random_state=123).fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033645 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 14842
# [LightGBM] [Info] Number of data points in the train set: 69999, number of used features: 193
# [LightGBM] [Info] Start training from score 1.789726

# %%
y_test_preds = model.predict(X_test) #We can then use our fitted model to predict the phones for each
                                        #indvidual in our test set, and see how well these predictions
                                        #match the truth.

# %%
from sklearn.metrics import r2_score, mean_squared_error
print(r2_score(y_test, y_test_preds)) #In this case we are predicting a continuous, numeric response.  Therefore, common
print(mean_squared_error(y_test, y_test_preds)) #metrics to assess fit include Rsquared and MSE.
# Out:
# 0.8245776939281154
# 0.3000926466174599

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (0.42.1)
# Requirement already satisfied: numpy in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (1.10.1)
# Requirement already satisfied: scikit-learn in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (4.65.0)
# Requirement already satisfied: packaging>20.9 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (23.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (0.57.1)
# Requirement already satisfied: cloudpickle in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from shap) (2.2.1)
# Requirement already satisfied: colorama in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from numba->shap) (0.40.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from pandas->shap) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from scikit-learn->shap) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\shinj\anaconda3\envs\anime\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %%
import shap

# %%
df_X = pd.DataFrame(X, columns=X.columns)
explainer = shap.Explainer(model.predict, X)

# %%
shap_values = explainer(df_X)
# Out:
# Permutation explainer: 100000it [2:05:17, 13.29it/s]

# %%
shap.summary_plot(
    shap_values = shap_values,
    features = X,
    max_display=16
)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
shap.plots.beeswarm(shap_values, order=shap_values.abs.max(0))
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# Clearly analyze the above results by omitting data that has no impact on the results.

# %%
drop_features = [
    'phones',
    'Customer_ID',
    'rev_Mean',
    'mou_Mean',
    'da_Mean',
    'ovrmou_Mean',
    'vceovr_Mean',
    'datovr_Mean',
    'roam_Mean',
    'change_mou',
    'change_rev',
    'drop_vce_Mean',
    'drop_dat_Mean',
    'blck_vce_Mean',
    'blck_dat_Mean',
    'unan_dat_Mean',
    'plcd_vce_Mean',
    'plcd_dat_Mean',
    'recv_vce_Mean',
    'recv_sms_Mean',
    'comp_vce_Mean',
    'comp_dat_Mean',
    'custcare_Mean',
    'ccrndmou_Mean',
    'inonemin_Mean',
    'threeway_Mean',
    'mou_cvce_Mean',
    'mou_cdat_Mean',
    'mou_rvce_Mean',
    'owylis_vce_Mean',
    'mouowylisv_Mean',
    'iwylis_vce_Mean',
    'mouiwylisv_Mean',
    'peak_vce_Mean',
    'peak_dat_Mean',
    'mou_pead_Mean',
    'opk_vce_Mean',
    'opk_dat_Mean',
    'mou_opkv_Mean',
    'mou_opkd_Mean',
    'drop_blk_Mean',
    'attempt_Mean',
    'complete_Mean',
    'callfwdv_Mean',
    'callwait_Mean',
    'churn',
    'actvsubs',
    'new_cell',
    'totcalls',
    'avgqty',
    'avg3mou',
    'avg3qty',
    'avg3rev',
    'avg6mou',
    'avg6qty',
    'prizm_social_one',
    'hnd_webcap',
    'truck',
    'rv',
    'ownrent',
    'lor',
    'dwlltype',
    'marital',
    'adults',
    'infobase',
    'income',
    'numbcars',
    'HHstatin',
    'dwllsize',
    'forgntvl',
    'ethnic',
    'kid0_2',
    'kid3_5',
    'kid6_10',
    'kid11_15',
    'kid16_17',
    'creditcd'
]

# %%
df, X, y = input_train_file(train_file_name, my_dtype)
# Out:
# missing value all count:input_train_file 342968
# missing value count per column:input_train_file rev_Mean              357
# mou_Mean              357
# totmrc_Mean           357
# da_Mean               357
# ovrmou_Mean           357
# ovrrev_Mean           357
# vceovr_Mean           357
# datovr_Mean           357
# roam_Mean             357
# change_mou            891
# change_rev            891
# drop_vce_Mean           0
# drop_dat_Mean           0
# blck_vce_Mean           0
# blck_dat_Mean           0
# unan_vce_Mean           0
# unan_dat_Mean           0
# plcd_vce_Mean           0
# plcd_dat_Mean           0
# recv_vce_Mean           0
# recv_sms_Mean           0
# comp_vce_Mean           0
# comp_dat_Mean           0
# custcare_Mean           0
# ccrndmou_Mean           0
# cc_mou_Mean             0
# inonemin_Mean           0
# threeway_Mean           0
# mou_cvce_Mean           0
# mou_cdat_Mean           0
# mou_rvce_Mean           0
# owylis_vce_Mean         0
# mouowylisv_Mean         0
# iwylis_vce_Mean         0
# mouiwylisv_Mean         0
# peak_vce_Mean           0
# peak_dat_Mean           0
# mou_peav_Mean           0
# mou_pead_Mean           0
# opk_vce_Mean            0
# opk_dat_Mean            0
# mou_opkv_Mean           0
# mou_opkd_Mean           0
# drop_blk_Mean           0
# attempt_Mean            0
# complete_Mean           0
# callfwdv_Mean           0
# callwait_Mean           0
# churn                   0
# months                  0
# uniqsubs                0
# actvsubs                0
# new_cell                0
# crclscod                0
# asl_flag                0
# totcalls                0
# totmou                  0
# totrev                  0
# adjrev                  0
# adjmou                  0
# adjqty                  0
# avgrev                  0
# avgmou                  0
# avgqty                  0
# avg3mou                 0
# avg3qty                 0
# avg3rev                 0
# avg6mou              2839
# avg6qty              2839
# avg6rev              2839
# prizm_social_one     7388
# area                   40
# dualband                1
# refurb_new              1
# hnd_price             847
# models                  1
# hnd_webcap          10189
# truck                1732
# rv                   1732
# ownrent             33706
# lor                 30190
# dwlltype            31909
# marital              1732
# adults              23019
# infobase            22079
# income              25436
# numbcars            49366
# HHstatin            37923
# dwllsize            38308
# forgntvl             1732
# ethnic               1732
# kid0_2               1732
# kid3_5               1732
# kid6_10              1732
# kid11_15             1732
# kid16_17             1732
# creditcd             1732
# eqpdays                 1
# Customer_ID             0
# dtype: int64

# %%
def tract_data(df):
    '''
    INPUT
    df - pandas dataframe

    OUTPUT
    X - A matrix holding all of the variables you want to consider when predicting the response
    y - the corresponding response vector

    This function cleans df using the following steps to produce X and y:
    1. Drop all the rows with no salaries
    2. Create X as all the columns that are not the Salary column
    3. Create y as the Salary column
    4. Drop the Salary, Respondent, and the ExpectedSalary columns
    5. For each numeric variable, fill the column with the mean value.
    6. Create dummy columns for all the categorical variables, drop the original columns
    '''
    # Drop rows with missing salary values
    df = df.dropna(subset=['phones'], axis=0)
    y = df['phones']

    #Drop respondent and expected salary columns
    df = df.drop(drop_features, axis=1)

    # Fill numeric columns with the mean
    num_vars = df.select_dtypes(include=['float', 'int']).columns
    for col in num_vars:
        df[col].fillna((df[col].mean()), inplace=True)

    # Dummy the categorical variables
    cat_vars = df.select_dtypes(include=['object']).copy().columns
    for var in  cat_vars:
        # for each cat add dummy var, drop original column
        df = pd.concat([df.drop(var, axis=1), pd.get_dummies(df[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)

    X = df
    return X, y

# %%
X, y = tract_data(df)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
model = lgb.LGBMRegressor(random_state=123).fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002773 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3788
# [LightGBM] [Info] Number of data points in the train set: 69999, number of used features: 77
# [LightGBM] [Info] Start training from score 1.786883

# %%
y_test_preds = model.predict(X_test) #We can then use our fitted model to predict the salary for each
                                        #indvidual in our test set, and see how well these predictions
                                        #match the truth.

# %% [markdown]
# Confirm Predict metrics

# %%
from sklearn.metrics import r2_score, mean_squared_error
print(r2_score(y_test, y_test_preds)) #In this case we are predicting a continuous, numeric response.  Therefore, common
print(mean_squared_error(y_test, y_test_preds)) #metrics to assess fit include Rsquared and MSE.
# Out:
# 0.8276081240806139
# 0.29274115375823684

# %% [markdown]
# What contribute to prediction ?

# %%
importance = pd.DataFrame(model.feature_importances_, index=X.columns, columns=['importance'])
importance = importance.sort_values('importance', ascending=False)
display(importance)
# Out:
#                                     importance
# eqpdays                                    379
# models                                     333
# months                                     272
# adjqty                                     217
# unan_vce_Mean                              207
# cc_mou_Mean                                173
# avg6rev                                    148
# hnd_price                                  137
# mou_peav_Mean                              134
# avgrev                                     129
# totmrc_Mean                                122
# ovrrev_Mean                                110
# avgmou                                     110
# totmou                                      99
# totrev                                      93
# adjrev                                      80
# adjmou                                      47
# dualband_Y                                  39
# uniqsubs                                    28
# refurb_new_R                                16
# asl_flag_Y                                  13
# area_NEW YORK CITY AREA                      9
# area_LOS ANGELES AREA                        8
# dualband_U                                   8
# dualband_T                                   8
# crclscod_B                                   8
# crclscod_AA                                  7
# crclscod_W                                   7
# area_OHIO AREA                               6
# area_CENTRAL/SOUTH TEXAS AREA                6
# crclscod_C                                   5
# area_HOUSTON AREA                            4
# area_GREAT LAKES AREA                        4
# area_NEW ENGLAND AREA                        3
# area_DALLAS AREA                             3
# area_CALIFORNIA NORTH AREA                   3
# crclscod_ZY                                  3
# crclscod_U                                   3
# crclscod_BA                                  3
# crclscod_EA                                  2
# crclscod_G                                   2
# area_SOUTHWEST AREA                          2
# crclscod_Z4                                  2
# crclscod_DA                                  1
# area_MIDWEST AREA                            1
# area_DC/MARYLAND/VIRGINIA AREA               1
# crclscod_K                                   1
# area_SOUTH FLORIDA AREA                      1
# crclscod_CY                                  1
# area_NORTHWEST/ROCKY MOUNTAIN AREA           1
# crclscod_V1                                  1
# crclscod_D5                                  0
# crclscod_D4                                  0
# area_CHICAGO AREA                            0
# crclscod_D2                                  0
# crclscod_D                                   0
# crclscod_CC                                  0
# crclscod_GA                                  0
# crclscod_CA                                  0
# crclscod_E                                   0
# area_NORTH FLORIDA AREA                      0
# crclscod_C2                                  0
# area_PHILADELPHIA AREA                       0
# crclscod_EM                                  0
# area_TENNESSEE AREA                          0
# crclscod_EF                                  0
# crclscod_B2                                  0
# crclscod_A2                                  0
# crclscod_C5                                  0
# crclscod_ZA                                  0
# crclscod_ZF                                  0
# crclscod_GY                                  0
# crclscod_H                                   0
# crclscod_I                                   0
# crclscod_A3                                  0
# crclscod_J                                   0
# crclscod_JF                                  0
# crclscod_L                                   0
# crclscod_M                                   0
# crclscod_O                                   0
# crclscod_P1                                  0
# crclscod_S                                   0
# crclscod_TP                                  0
# crclscod_E4                                  0
# crclscod_U1                                  0
# crclscod_V                                   0
# crclscod_E2                                  0
# crclscod_Y                                   0
# crclscod_Z                                   0
# crclscod_Z1                                  0
# crclscod_Z2                                  0
# crclscod_EC                                  0
# crclscod_Z5                                  0
# crclscod_IF                                  0

# %%
df_X = pd.DataFrame(X, columns=X.columns)
explainer = shap.Explainer(model.predict, X)

# %%
shap_values = explainer(df_X)
# Out:
# Permutation explainer: 100000it [1:06:15, 25.09it/s]

# %%
shap.summary_plot(
    shap_values = shap_values,
    features = X,
    max_display=32
)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# In addtion, we created an AI to predict phones in the figure below and found that models, months, and adjqty have large positive correlations. Also, months is negatively correlated with eqpdays.

# %%
shap.plots.beeswarm(shap_values, order=shap_values.abs.max(0))
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# For higher revenue customers, try to get them to use calls more often and
# and to encourage them to use more value-added, higher-priced terminals.
# This will increase the number of terminals issued for life.
